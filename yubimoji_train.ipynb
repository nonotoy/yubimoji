# %% [markdown]
# <a href="https://colab.research.google.com/github/nonotoy/yubimoji/blob/main/yubimoji_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import csv
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, LSTM, BatchNormalization, Dropout, GlobalAveragePooling1D, Flatten

from tensorflow.python.client import device_lib
device_lib.list_local_devices()

dataset = '/content/drive/MyDrive/Colab Notebooks/JSL/point_history_normalised.csv'

model_save_path = '/content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5'
tflite_save_path = '/content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/keypoint_classifier.tflite'

# %%
# モデルのパラメータ
n_features = 40  # ランドマークの数
n_sequence = 30  # シーケンス長 (調整が必要)
n_classes = 76 # 出力クラス (指文字) の数

# 2列目以降を学習データとする
X_dataset = np.loadtxt(dataset, delimiter=',', dtype='float32', usecols=list(range(1, n_features+1))) # (20730, 40)

# 1列目を正解ラベルとする
y_dataset = np.loadtxt(dataset, delimiter=',', dtype='int32', usecols=(0))

# ラベルをワンホットエンコードする
y_dataset = to_categorical(y_dataset, num_classes=n_classes) # (20730, 76)

# %%
print(X_dataset.shape[0] // n_sequence)  # 691
# Out:
# 691

# %%
# サンプル数を n_sequence で割り切れるように調整
total_samples = len(X_dataset)
max_samples = total_samples - total_samples % n_sequence # 20,730 = 20,730 - 0
print(max_samples)
# Out:
# 20730

# %%
X_dataset = X_dataset[:max_samples]
y_dataset = y_dataset[:max_samples]
X_dataset = X_dataset.reshape(-1, n_sequence, n_features) # (691, 30, 40)
y_dataset = y_dataset.reshape(-1, n_sequence, n_classes) # (691, 30, 76)

# %%
print(X_dataset.shape)
print(y_dataset.shape)
# Out:
# (691, 30, 40)
# (691, 30, 76)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_dataset, y_dataset, train_size=0.75, random_state=42)

print(y_train.shape)
print(y_test.shape)

# %%
y_train_last = y_train[:, -1, :]
y_test_last = y_test[:, -1, :]

print(y_train_last.shape)
print(y_test_last.shape)
# Out:
# (518, 76)
# (173, 76)

# %% [markdown]
# ### LSTMモデル

# %%
# モデルの定義
model = Sequential([
    LSTM(128, input_shape=(n_sequence, n_features), return_sequences=False),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(n_classes, activation='softmax')
])

# モデルのコンパイル
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# モデルチェックポイントのコールバック
cp_callback = tf.keras.callbacks.ModelCheckpoint(model_save_path, verbose=1, save_weights_only=False)
# 早期打ち切り用コールバック
es_callback = tf.keras.callbacks.EarlyStopping(patience=20, verbose=1)

# モデルのサマリー表示
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_5 (LSTM)               (None, 128)               86528
#
#  dropout_10 (Dropout)        (None, 128)               0
#
#  dense_10 (Dense)            (None, 64)                8256
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_11 (Dense)            (None, 76)                4940
#
# =================================================================
# Total params: 99724 (389.55 KB)
# Trainable params: 99724 (389.55 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(
    X_train,
    y_train_last,
    epochs=1000,
    batch_size=128,
    validation_data=(X_test, y_test_last),
    callbacks=[cp_callback, es_callback]
)
# Out:
# Epoch 1/1000
# 1/5 [=====>........................] - ETA: 7s - loss: 4.3778 - accuracy: 0.0312
# Epoch 1: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 5/5 [==============================] - 3s 343ms/step - loss: 4.3525 - accuracy: 0.0154 - val_loss: 4.2737 - val_accuracy: 0.0520
# Epoch 2/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 4.2178 - accuracy: 0.0703
# Epoch 2: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 4.1946 - accuracy: 0.0560 - val_loss: 4.2048 - val_accuracy: 0.0694
# Epoch 3/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 4.1242 - accuracy: 0.0859
# Epoch 3: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 4.1193 - accuracy: 0.0772 - val_loss: 4.1458 - val_accuracy: 0.0867
# Epoch 4/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 3.9811 - accuracy: 0.1328
# Epoch 4: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 4.0222 - accuracy: 0.1062 - val_loss: 4.0950 - val_accuracy: 0.0867
# Epoch 5/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 3.9635 - accuracy: 0.1250
# Epoch 5: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 3.9550 - accuracy: 0.1332 - val_loss: 4.0473 - val_accuracy: 0.1387
# Epoch 6/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 3.9193 - accuracy: 0.1250
# Epoch 6: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 3.8828 - accuracy: 0.1293 - val_loss: 3.9984 - val_accuracy: 0.1329
# Epoch 7/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 3.8440 - accuracy: 0.1484
# Epoch 7: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 3.8224 - accuracy: 0.1506 - val_loss: 3.9435 - val_accuracy: 0.1387
# Epoch 8/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 3.6828 - accuracy: 0.2188
# Epoch 8: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 3.7204 - accuracy: 0.1892 - val_loss: 3.8853 - val_accuracy: 0.1329
# Epoch 9/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 3.6535 - accuracy: 0.1562
# Epoch 9: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 3.6387 - accuracy: 0.2066 - val_loss: 3.8235 - val_accuracy: 0.1387
# Epoch 10/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 3.5372 - accuracy: 0.2422
# Epoch 10: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 3.5494 - accuracy: 0.1931 - val_loss: 3.7435 - val_accuracy: 0.1272
# Epoch 11/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 3.4943 - accuracy: 0.1875
# Epoch 11: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 3.4612 - accuracy: 0.1969 - val_loss: 3.6791 - val_accuracy: 0.1329
# Epoch 12/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 3.5169 - accuracy: 0.1172
# Epoch 12: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 19ms/step - loss: 3.4113 - accuracy: 0.1950 - val_loss: 3.6352 - val_accuracy: 0.1272
# Epoch 13/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 3.3315 - accuracy: 0.1562
# Epoch 13: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 3.3204 - accuracy: 0.1757 - val_loss: 3.5752 - val_accuracy: 0.1387
# Epoch 14/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 3.2369 - accuracy: 0.2266
# Epoch 14: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 3.2186 - accuracy: 0.2297 - val_loss: 3.4943 - val_accuracy: 0.1503
# Epoch 15/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 3.0734 - accuracy: 0.3281
# Epoch 15: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 3.1428 - accuracy: 0.2471 - val_loss: 3.4532 - val_accuracy: 0.1734
# Epoch 16/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 3.0891 - accuracy: 0.2578
# Epoch 16: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 3.0734 - accuracy: 0.2548 - val_loss: 3.3972 - val_accuracy: 0.1734
# Epoch 17/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 3.0249 - accuracy: 0.2734
# Epoch 17: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 3.0565 - accuracy: 0.2413 - val_loss: 3.3729 - val_accuracy: 0.1908
# Epoch 18/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 3.0401 - accuracy: 0.2656
# Epoch 18: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 3.0182 - accuracy: 0.2529 - val_loss: 3.3035 - val_accuracy: 0.2370
# Epoch 19/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 3.0919 - accuracy: 0.2812
# Epoch 19: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 2.9320 - accuracy: 0.2934 - val_loss: 3.2322 - val_accuracy: 0.2197
# Epoch 20/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 2.7662 - accuracy: 0.3359
# Epoch 20: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 32ms/step - loss: 2.8772 - accuracy: 0.2973 - val_loss: 3.1832 - val_accuracy: 0.2139
# Epoch 21/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 2.8540 - accuracy: 0.2422
# Epoch 21: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 2.8153 - accuracy: 0.2857 - val_loss: 3.1291 - val_accuracy: 0.2312
# Epoch 22/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 2.7296 - accuracy: 0.2891
# Epoch 22: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 2.7369 - accuracy: 0.2819 - val_loss: 3.0656 - val_accuracy: 0.2081
# Epoch 23/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 2.4829 - accuracy: 0.3750
# Epoch 23: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6584 - accuracy: 0.3108 - val_loss: 3.0209 - val_accuracy: 0.2312
# Epoch 24/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 2.6318 - accuracy: 0.2891
# Epoch 24: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 2.6359 - accuracy: 0.3108 - val_loss: 2.9925 - val_accuracy: 0.2312
# Epoch 25/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 2.5367 - accuracy: 0.3750
# Epoch 25: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 2.5627 - accuracy: 0.3398 - val_loss: 2.9235 - val_accuracy: 0.2543
# Epoch 26/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 2.4472 - accuracy: 0.4297
# Epoch 26: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 2.5290 - accuracy: 0.3880 - val_loss: 2.8733 - val_accuracy: 0.2543
# Epoch 27/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 2.4490 - accuracy: 0.3828
# Epoch 27: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4945 - accuracy: 0.3610 - val_loss: 2.8083 - val_accuracy: 0.2543
# Epoch 28/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 2.5721 - accuracy: 0.3594
# Epoch 28: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 2.4484 - accuracy: 0.3514 - val_loss: 2.8002 - val_accuracy: 0.2543
# Epoch 29/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 2.4885 - accuracy: 0.3125
# Epoch 29: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 2.4670 - accuracy: 0.3243 - val_loss: 2.7480 - val_accuracy: 0.2717
# Epoch 30/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 2.4928 - accuracy: 0.3672
# Epoch 30: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 2.3963 - accuracy: 0.3687 - val_loss: 2.6935 - val_accuracy: 0.2717
# Epoch 31/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 2.3719 - accuracy: 0.3047
# Epoch 31: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 2.3629 - accuracy: 0.3591 - val_loss: 2.6416 - val_accuracy: 0.3006
# Epoch 32/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 2.3237 - accuracy: 0.3672
# Epoch 32: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 2.3404 - accuracy: 0.3649 - val_loss: 2.6304 - val_accuracy: 0.2832
# Epoch 33/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 2.3731 - accuracy: 0.3672
# Epoch 33: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 2.3204 - accuracy: 0.3668 - val_loss: 2.5988 - val_accuracy: 0.2948
# Epoch 34/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 2.2136 - accuracy: 0.4062
# Epoch 34: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 2.2538 - accuracy: 0.4112 - val_loss: 2.5728 - val_accuracy: 0.2948
# Epoch 35/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 2.3453 - accuracy: 0.3672
# Epoch 35: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 2.2494 - accuracy: 0.3861 - val_loss: 2.5346 - val_accuracy: 0.2832
# Epoch 36/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 2.2320 - accuracy: 0.4141
# Epoch 36: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 2.1810 - accuracy: 0.3977 - val_loss: 2.5206 - val_accuracy: 0.2775
# Epoch 37/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 2.2654 - accuracy: 0.3828
# Epoch 37: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 2.1756 - accuracy: 0.4189 - val_loss: 2.5300 - val_accuracy: 0.2832
# Epoch 38/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 2.2185 - accuracy: 0.4297
# Epoch 38: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 2.1938 - accuracy: 0.3822 - val_loss: 2.5026 - val_accuracy: 0.2428
# Epoch 39/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 2.3122 - accuracy: 0.3359
# Epoch 39: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 2.1234 - accuracy: 0.4131 - val_loss: 2.4234 - val_accuracy: 0.2890
# Epoch 40/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 2.1447 - accuracy: 0.3906
# Epoch 40: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 31ms/step - loss: 2.0988 - accuracy: 0.4093 - val_loss: 2.3503 - val_accuracy: 0.3006
# Epoch 41/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 2.0446 - accuracy: 0.4531
# Epoch 41: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 2.0310 - accuracy: 0.4653 - val_loss: 2.3103 - val_accuracy: 0.3121
# Epoch 42/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 2.0011 - accuracy: 0.4844
# Epoch 42: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.9578 - accuracy: 0.4498 - val_loss: 2.3001 - val_accuracy: 0.3179
# Epoch 43/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 2.1122 - accuracy: 0.4141
# Epoch 43: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.9509 - accuracy: 0.4459 - val_loss: 2.2608 - val_accuracy: 0.3179
# Epoch 44/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.8634 - accuracy: 0.5000
# Epoch 44: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.9337 - accuracy: 0.4421 - val_loss: 2.2511 - val_accuracy: 0.3064
# Epoch 45/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.9532 - accuracy: 0.4297
# Epoch 45: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 1.9466 - accuracy: 0.4344 - val_loss: 2.2110 - val_accuracy: 0.3295
# Epoch 46/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.8426 - accuracy: 0.4453
# Epoch 46: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 1.8134 - accuracy: 0.4942 - val_loss: 2.1804 - val_accuracy: 0.3353
# Epoch 47/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.7782 - accuracy: 0.4766
# Epoch 47: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 1.8326 - accuracy: 0.4691 - val_loss: 2.1782 - val_accuracy: 0.3584
# Epoch 48/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.8154 - accuracy: 0.4375
# Epoch 48: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.8243 - accuracy: 0.4614 - val_loss: 2.1787 - val_accuracy: 0.3121
# Epoch 49/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.7074 - accuracy: 0.5156
# Epoch 49: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 1.7742 - accuracy: 0.4710 - val_loss: 2.1343 - val_accuracy: 0.3237
# Epoch 50/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.7405 - accuracy: 0.4922
# Epoch 50: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 1.8168 - accuracy: 0.4517 - val_loss: 2.1106 - val_accuracy: 0.3064
# Epoch 51/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.7070 - accuracy: 0.4922
# Epoch 51: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.7603 - accuracy: 0.4807 - val_loss: 2.0757 - val_accuracy: 0.3179
# Epoch 52/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.7108 - accuracy: 0.5391
# Epoch 52: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.7382 - accuracy: 0.4672 - val_loss: 2.0841 - val_accuracy: 0.3237
# Epoch 53/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.7822 - accuracy: 0.4844
# Epoch 53: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.7648 - accuracy: 0.4865 - val_loss: 2.1022 - val_accuracy: 0.3121
# Epoch 54/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.8001 - accuracy: 0.4531
# Epoch 54: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 1.7778 - accuracy: 0.4595 - val_loss: 2.0528 - val_accuracy: 0.3295
# Epoch 55/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.9112 - accuracy: 0.3906
# Epoch 55: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.7437 - accuracy: 0.4672 - val_loss: 2.0124 - val_accuracy: 0.3584
# Epoch 56/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.8597 - accuracy: 0.4062
# Epoch 56: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.6886 - accuracy: 0.4923 - val_loss: 2.0602 - val_accuracy: 0.3179
# Epoch 57/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.7729 - accuracy: 0.4141
# Epoch 57: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.7261 - accuracy: 0.4595 - val_loss: 1.9943 - val_accuracy: 0.3699
# Epoch 58/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.6051 - accuracy: 0.5156
# Epoch 58: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.6925 - accuracy: 0.4865 - val_loss: 1.9861 - val_accuracy: 0.3699
# Epoch 59/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.6461 - accuracy: 0.5469
# Epoch 59: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 1.6773 - accuracy: 0.4981 - val_loss: 1.9687 - val_accuracy: 0.3410
# Epoch 60/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.6034 - accuracy: 0.4922
# Epoch 60: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.6682 - accuracy: 0.4884 - val_loss: 1.9124 - val_accuracy: 0.3642
# Epoch 61/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.5953 - accuracy: 0.4609
# Epoch 61: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 31ms/step - loss: 1.6293 - accuracy: 0.4730 - val_loss: 1.9441 - val_accuracy: 0.3699
# Epoch 62/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.6933 - accuracy: 0.4375
# Epoch 62: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.6589 - accuracy: 0.4865 - val_loss: 1.9406 - val_accuracy: 0.3642
# Epoch 63/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.6046 - accuracy: 0.5469
# Epoch 63: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.6798 - accuracy: 0.4730 - val_loss: 1.9303 - val_accuracy: 0.3237
# Epoch 64/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.7559 - accuracy: 0.3750
# Epoch 64: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 19ms/step - loss: 1.6243 - accuracy: 0.5019 - val_loss: 1.8766 - val_accuracy: 0.3699
# Epoch 65/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.6098 - accuracy: 0.5547
# Epoch 65: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.6411 - accuracy: 0.5019 - val_loss: 1.8618 - val_accuracy: 0.3526
# Epoch 66/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.5790 - accuracy: 0.5625
# Epoch 66: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.6622 - accuracy: 0.4807 - val_loss: 1.8428 - val_accuracy: 0.3931
# Epoch 67/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.7113 - accuracy: 0.4688
# Epoch 67: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.6052 - accuracy: 0.5212 - val_loss: 1.8143 - val_accuracy: 0.3988
# Epoch 68/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.5145 - accuracy: 0.5234
# Epoch 68: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 1.5558 - accuracy: 0.5328 - val_loss: 1.7988 - val_accuracy: 0.3642
# Epoch 69/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.5399 - accuracy: 0.5156
# Epoch 69: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 1.5429 - accuracy: 0.4942 - val_loss: 1.8203 - val_accuracy: 0.3699
# Epoch 70/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.5885 - accuracy: 0.5000
# Epoch 70: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.5401 - accuracy: 0.5270 - val_loss: 1.8449 - val_accuracy: 0.4162
# Epoch 71/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.5226 - accuracy: 0.5547
# Epoch 71: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4756 - accuracy: 0.5309 - val_loss: 1.8383 - val_accuracy: 0.3873
# Epoch 72/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.3731 - accuracy: 0.6172
# Epoch 72: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4606 - accuracy: 0.5405 - val_loss: 1.8101 - val_accuracy: 0.3815
# Epoch 73/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.4332 - accuracy: 0.5625
# Epoch 73: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 1.4529 - accuracy: 0.5328 - val_loss: 1.7943 - val_accuracy: 0.4220
# Epoch 74/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.4692 - accuracy: 0.5234
# Epoch 74: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.4554 - accuracy: 0.5444 - val_loss: 1.8293 - val_accuracy: 0.3873
# Epoch 75/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.3607 - accuracy: 0.5703
# Epoch 75: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.4514 - accuracy: 0.5502 - val_loss: 1.7981 - val_accuracy: 0.3757
# Epoch 76/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.4390 - accuracy: 0.5625
# Epoch 76: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.4188 - accuracy: 0.5734 - val_loss: 1.7624 - val_accuracy: 0.3815
# Epoch 77/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.3072 - accuracy: 0.5781
# Epoch 77: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 1.4323 - accuracy: 0.5251 - val_loss: 1.7349 - val_accuracy: 0.4104
# Epoch 78/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.4037 - accuracy: 0.5312
# Epoch 78: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 1.4207 - accuracy: 0.5193 - val_loss: 1.7566 - val_accuracy: 0.3815
# Epoch 79/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.4947 - accuracy: 0.5547
# Epoch 79: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 1.4373 - accuracy: 0.5521 - val_loss: 1.7334 - val_accuracy: 0.4104
# Epoch 80/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.3633 - accuracy: 0.5469
# Epoch 80: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 1.3736 - accuracy: 0.5734 - val_loss: 1.6936 - val_accuracy: 0.4046
# Epoch 81/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.3398 - accuracy: 0.5781
# Epoch 81: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 27ms/step - loss: 1.3332 - accuracy: 0.6004 - val_loss: 1.6833 - val_accuracy: 0.4046
# Epoch 82/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.3474 - accuracy: 0.5703
# Epoch 82: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3179 - accuracy: 0.5792 - val_loss: 1.6480 - val_accuracy: 0.4277
# Epoch 83/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.3368 - accuracy: 0.5859
# Epoch 83: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3115 - accuracy: 0.5830 - val_loss: 1.6500 - val_accuracy: 0.4162
# Epoch 84/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.2269 - accuracy: 0.6250
# Epoch 84: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 1.3644 - accuracy: 0.5714 - val_loss: 1.6831 - val_accuracy: 0.4046
# Epoch 85/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.3177 - accuracy: 0.6172
# Epoch 85: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2755 - accuracy: 0.5907 - val_loss: 1.6526 - val_accuracy: 0.4220
# Epoch 86/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.3932 - accuracy: 0.5078
# Epoch 86: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 1.3247 - accuracy: 0.5637 - val_loss: 1.6406 - val_accuracy: 0.4162
# Epoch 87/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.2728 - accuracy: 0.6172
# Epoch 87: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 1.3263 - accuracy: 0.5560 - val_loss: 1.6177 - val_accuracy: 0.4046
# Epoch 88/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.3080 - accuracy: 0.5859
# Epoch 88: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 1.3046 - accuracy: 0.5907 - val_loss: 1.6389 - val_accuracy: 0.4335
# Epoch 89/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.1950 - accuracy: 0.6250
# Epoch 89: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 1.3104 - accuracy: 0.5734 - val_loss: 1.6542 - val_accuracy: 0.4393
# Epoch 90/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.2455 - accuracy: 0.6172
# Epoch 90: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 1.3468 - accuracy: 0.5425 - val_loss: 1.6318 - val_accuracy: 0.4104
# Epoch 91/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.1634 - accuracy: 0.6484
# Epoch 91: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 1.2468 - accuracy: 0.5946 - val_loss: 1.6136 - val_accuracy: 0.4162
# Epoch 92/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.1917 - accuracy: 0.6250
# Epoch 92: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2403 - accuracy: 0.5927 - val_loss: 1.6272 - val_accuracy: 0.3873
# Epoch 93/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.2868 - accuracy: 0.5781
# Epoch 93: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2590 - accuracy: 0.6100 - val_loss: 1.6236 - val_accuracy: 0.4104
# Epoch 94/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.2045 - accuracy: 0.6250
# Epoch 94: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2649 - accuracy: 0.5734 - val_loss: 1.5984 - val_accuracy: 0.3988
# Epoch 95/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.2470 - accuracy: 0.5703
# Epoch 95: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2616 - accuracy: 0.5907 - val_loss: 1.5665 - val_accuracy: 0.4046
# Epoch 96/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.2447 - accuracy: 0.5859
# Epoch 96: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2856 - accuracy: 0.5849 - val_loss: 1.5709 - val_accuracy: 0.4451
# Epoch 97/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.1752 - accuracy: 0.6406
# Epoch 97: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 1.2342 - accuracy: 0.5946 - val_loss: 1.6094 - val_accuracy: 0.4451
# Epoch 98/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.2116 - accuracy: 0.6484
# Epoch 98: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2187 - accuracy: 0.6062 - val_loss: 1.6395 - val_accuracy: 0.4046
# Epoch 99/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.1073 - accuracy: 0.6172
# Epoch 99: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 1.2600 - accuracy: 0.5579 - val_loss: 1.6566 - val_accuracy: 0.4046
# Epoch 100/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.1271 - accuracy: 0.6172
# Epoch 100: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.2496 - accuracy: 0.5772 - val_loss: 1.6427 - val_accuracy: 0.4277
# Epoch 101/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.2809 - accuracy: 0.5703
# Epoch 101: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2209 - accuracy: 0.6023 - val_loss: 1.6278 - val_accuracy: 0.4277
# Epoch 102/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.2076 - accuracy: 0.6094
# Epoch 102: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 33ms/step - loss: 1.3101 - accuracy: 0.5734 - val_loss: 1.5957 - val_accuracy: 0.4335
# Epoch 103/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.1694 - accuracy: 0.5938
# Epoch 103: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 1.2478 - accuracy: 0.5792 - val_loss: 1.5396 - val_accuracy: 0.4624
# Epoch 104/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.2862 - accuracy: 0.5625
# Epoch 104: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.2356 - accuracy: 0.5695 - val_loss: 1.5325 - val_accuracy: 0.4393
# Epoch 105/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.2003 - accuracy: 0.6406
# Epoch 105: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 23ms/step - loss: 1.1973 - accuracy: 0.6371 - val_loss: 1.5366 - val_accuracy: 0.4162
# Epoch 106/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.1641 - accuracy: 0.6250
# Epoch 106: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.2407 - accuracy: 0.6004 - val_loss: 1.5623 - val_accuracy: 0.4277
# Epoch 107/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.1734 - accuracy: 0.6172
# Epoch 107: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 19ms/step - loss: 1.2418 - accuracy: 0.5714 - val_loss: 1.5608 - val_accuracy: 0.4624
# Epoch 108/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.1958 - accuracy: 0.6250
# Epoch 108: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.2324 - accuracy: 0.5792 - val_loss: 1.5988 - val_accuracy: 0.4162
# Epoch 109/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.1633 - accuracy: 0.6562
# Epoch 109: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.2240 - accuracy: 0.6042 - val_loss: 1.5821 - val_accuracy: 0.4335
# Epoch 110/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.3258 - accuracy: 0.5234
# Epoch 110: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.2173 - accuracy: 0.5888 - val_loss: 1.5251 - val_accuracy: 0.4451
# Epoch 111/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.1856 - accuracy: 0.6250
# Epoch 111: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.1656 - accuracy: 0.6158 - val_loss: 1.4866 - val_accuracy: 0.4624
# Epoch 112/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.1197 - accuracy: 0.6094
# Epoch 112: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.1647 - accuracy: 0.6081 - val_loss: 1.4507 - val_accuracy: 0.4798
# Epoch 113/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.1386 - accuracy: 0.6094
# Epoch 113: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.1242 - accuracy: 0.6429 - val_loss: 1.4442 - val_accuracy: 0.4855
# Epoch 114/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0280 - accuracy: 0.6484
# Epoch 114: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.1229 - accuracy: 0.6274 - val_loss: 1.4610 - val_accuracy: 0.4798
# Epoch 115/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.1277 - accuracy: 0.6328
# Epoch 115: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 1.1264 - accuracy: 0.6525 - val_loss: 1.4880 - val_accuracy: 0.4509
# Epoch 116/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0989 - accuracy: 0.6641
# Epoch 116: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.1714 - accuracy: 0.5869 - val_loss: 1.4951 - val_accuracy: 0.4393
# Epoch 117/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.1389 - accuracy: 0.6406
# Epoch 117: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.1827 - accuracy: 0.5907 - val_loss: 1.5054 - val_accuracy: 0.4566
# Epoch 118/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0922 - accuracy: 0.6172
# Epoch 118: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.0786 - accuracy: 0.6332 - val_loss: 1.5024 - val_accuracy: 0.4451
# Epoch 119/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0830 - accuracy: 0.6406
# Epoch 119: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.0779 - accuracy: 0.6332 - val_loss: 1.4870 - val_accuracy: 0.4277
# Epoch 120/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.1180 - accuracy: 0.6172
# Epoch 120: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.0980 - accuracy: 0.6120 - val_loss: 1.4679 - val_accuracy: 0.4220
# Epoch 121/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.1553 - accuracy: 0.5469
# Epoch 121: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.1263 - accuracy: 0.6255 - val_loss: 1.4659 - val_accuracy: 0.4451
# Epoch 122/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0940 - accuracy: 0.6250
# Epoch 122: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 31ms/step - loss: 1.0935 - accuracy: 0.6274 - val_loss: 1.4754 - val_accuracy: 0.4220
# Epoch 123/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0229 - accuracy: 0.6328
# Epoch 123: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.1027 - accuracy: 0.6197 - val_loss: 1.4807 - val_accuracy: 0.4046
# Epoch 124/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0802 - accuracy: 0.6797
# Epoch 124: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.0835 - accuracy: 0.6332 - val_loss: 1.4686 - val_accuracy: 0.4162
# Epoch 125/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.1030 - accuracy: 0.6250
# Epoch 125: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 1.1056 - accuracy: 0.6351 - val_loss: 1.4377 - val_accuracy: 0.4624
# Epoch 126/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0209 - accuracy: 0.6406
# Epoch 126: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.1168 - accuracy: 0.6178 - val_loss: 1.4242 - val_accuracy: 0.4393
# Epoch 127/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9562 - accuracy: 0.6562
# Epoch 127: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.0596 - accuracy: 0.6158 - val_loss: 1.4392 - val_accuracy: 0.4162
# Epoch 128/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0398 - accuracy: 0.6328
# Epoch 128: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.0890 - accuracy: 0.6293 - val_loss: 1.4245 - val_accuracy: 0.4393
# Epoch 129/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0245 - accuracy: 0.6875
# Epoch 129: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.0422 - accuracy: 0.6486 - val_loss: 1.4373 - val_accuracy: 0.4624
# Epoch 130/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.2667 - accuracy: 0.5625
# Epoch 130: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.0884 - accuracy: 0.6236 - val_loss: 1.4311 - val_accuracy: 0.4566
# Epoch 131/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0862 - accuracy: 0.6016
# Epoch 131: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.0507 - accuracy: 0.6390 - val_loss: 1.4410 - val_accuracy: 0.4393
# Epoch 132/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0664 - accuracy: 0.6016
# Epoch 132: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.0605 - accuracy: 0.6178 - val_loss: 1.4617 - val_accuracy: 0.4393
# Epoch 133/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0413 - accuracy: 0.5938
# Epoch 133: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.0343 - accuracy: 0.6332 - val_loss: 1.4440 - val_accuracy: 0.4566
# Epoch 134/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0311 - accuracy: 0.7109
# Epoch 134: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 1.0235 - accuracy: 0.6544 - val_loss: 1.4241 - val_accuracy: 0.4393
# Epoch 135/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9237 - accuracy: 0.6875
# Epoch 135: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 0.9989 - accuracy: 0.6564 - val_loss: 1.4276 - val_accuracy: 0.4451
# Epoch 136/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8830 - accuracy: 0.7344
# Epoch 136: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.0023 - accuracy: 0.6602 - val_loss: 1.4009 - val_accuracy: 0.4451
# Epoch 137/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9933 - accuracy: 0.6562
# Epoch 137: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.0145 - accuracy: 0.6525 - val_loss: 1.3782 - val_accuracy: 0.4624
# Epoch 138/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0201 - accuracy: 0.6484
# Epoch 138: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.0649 - accuracy: 0.6390 - val_loss: 1.3433 - val_accuracy: 0.4798
# Epoch 139/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9746 - accuracy: 0.6797
# Epoch 139: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.9859 - accuracy: 0.6602 - val_loss: 1.3507 - val_accuracy: 0.4509
# Epoch 140/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0362 - accuracy: 0.6094
# Epoch 140: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 19ms/step - loss: 1.0115 - accuracy: 0.6313 - val_loss: 1.3524 - val_accuracy: 0.4566
# Epoch 141/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0310 - accuracy: 0.5781
# Epoch 141: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.0241 - accuracy: 0.6197 - val_loss: 1.3278 - val_accuracy: 0.4566
# Epoch 142/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9611 - accuracy: 0.6641
# Epoch 142: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 0.9922 - accuracy: 0.6544 - val_loss: 1.3091 - val_accuracy: 0.4624
# Epoch 143/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0216 - accuracy: 0.6172
# Epoch 143: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 29ms/step - loss: 0.9516 - accuracy: 0.6544 - val_loss: 1.2955 - val_accuracy: 0.4798
# Epoch 144/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0256 - accuracy: 0.6250
# Epoch 144: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 0.9525 - accuracy: 0.6506 - val_loss: 1.2938 - val_accuracy: 0.4624
# Epoch 145/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9063 - accuracy: 0.6641
# Epoch 145: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.9428 - accuracy: 0.6680 - val_loss: 1.3032 - val_accuracy: 0.4682
# Epoch 146/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8108 - accuracy: 0.7656
# Epoch 146: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 19ms/step - loss: 0.9100 - accuracy: 0.6834 - val_loss: 1.3315 - val_accuracy: 0.4451
# Epoch 147/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7997 - accuracy: 0.7422
# Epoch 147: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.8806 - accuracy: 0.6969 - val_loss: 1.3572 - val_accuracy: 0.4393
# Epoch 148/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9015 - accuracy: 0.6641
# Epoch 148: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.8959 - accuracy: 0.6718 - val_loss: 1.3181 - val_accuracy: 0.4682
# Epoch 149/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9168 - accuracy: 0.6797
# Epoch 149: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 0.8961 - accuracy: 0.6757 - val_loss: 1.3053 - val_accuracy: 0.4509
# Epoch 150/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0251 - accuracy: 0.6406
# Epoch 150: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.9284 - accuracy: 0.6853 - val_loss: 1.3466 - val_accuracy: 0.4624
# Epoch 151/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8498 - accuracy: 0.7031
# Epoch 151: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.8991 - accuracy: 0.6564 - val_loss: 1.3521 - val_accuracy: 0.4682
# Epoch 152/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9537 - accuracy: 0.6719
# Epoch 152: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.9012 - accuracy: 0.6931 - val_loss: 1.3512 - val_accuracy: 0.4740
# Epoch 153/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9435 - accuracy: 0.6328
# Epoch 153: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.9778 - accuracy: 0.6351 - val_loss: 1.3338 - val_accuracy: 0.4740
# Epoch 154/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8632 - accuracy: 0.7422
# Epoch 154: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.9536 - accuracy: 0.6564 - val_loss: 1.3468 - val_accuracy: 0.4393
# Epoch 155/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8060 - accuracy: 0.7344
# Epoch 155: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.8816 - accuracy: 0.6776 - val_loss: 1.3574 - val_accuracy: 0.4509
# Epoch 156/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9393 - accuracy: 0.6797
# Epoch 156: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.0121 - accuracy: 0.6313 - val_loss: 1.3174 - val_accuracy: 0.4855
# Epoch 157/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8425 - accuracy: 0.7109
# Epoch 157: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.8964 - accuracy: 0.6795 - val_loss: 1.3062 - val_accuracy: 0.4624
# Epoch 158/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9976 - accuracy: 0.6016
# Epoch 158: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 0.9151 - accuracy: 0.6660 - val_loss: 1.3038 - val_accuracy: 0.4682
# Epoch 159/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8574 - accuracy: 0.6875
# Epoch 159: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 0.9895 - accuracy: 0.6429 - val_loss: 1.3086 - val_accuracy: 0.4393
# Epoch 160/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0271 - accuracy: 0.6250
# Epoch 160: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.9562 - accuracy: 0.6486 - val_loss: 1.2790 - val_accuracy: 0.4971
# Epoch 161/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8556 - accuracy: 0.6875
# Epoch 161: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 19ms/step - loss: 0.9425 - accuracy: 0.6467 - val_loss: 1.2958 - val_accuracy: 0.4971
# Epoch 162/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9513 - accuracy: 0.6484
# Epoch 162: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 0.9571 - accuracy: 0.6486 - val_loss: 1.3235 - val_accuracy: 0.4971
# Epoch 163/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9131 - accuracy: 0.6641
# Epoch 163: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 29ms/step - loss: 0.9411 - accuracy: 0.6564 - val_loss: 1.3327 - val_accuracy: 0.4798
# Epoch 164/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9135 - accuracy: 0.7031
# Epoch 164: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.9648 - accuracy: 0.6429 - val_loss: 1.3715 - val_accuracy: 0.4335
# Epoch 165/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0183 - accuracy: 0.6250
# Epoch 165: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.9418 - accuracy: 0.6641 - val_loss: 1.3656 - val_accuracy: 0.4566
# Epoch 166/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9580 - accuracy: 0.6562
# Epoch 166: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 19ms/step - loss: 0.9183 - accuracy: 0.6853 - val_loss: 1.3753 - val_accuracy: 0.4624
# Epoch 167/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0719 - accuracy: 0.6094
# Epoch 167: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.0269 - accuracy: 0.6351 - val_loss: 1.3747 - val_accuracy: 0.4624
# Epoch 168/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0126 - accuracy: 0.5703
# Epoch 168: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.9193 - accuracy: 0.6622 - val_loss: 1.3375 - val_accuracy: 0.4509
# Epoch 169/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9026 - accuracy: 0.6797
# Epoch 169: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.9120 - accuracy: 0.6641 - val_loss: 1.2978 - val_accuracy: 0.4624
# Epoch 170/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9397 - accuracy: 0.6484
# Epoch 170: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.9414 - accuracy: 0.6486 - val_loss: 1.2742 - val_accuracy: 0.4740
# Epoch 171/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0064 - accuracy: 0.6328
# Epoch 171: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.9336 - accuracy: 0.6332 - val_loss: 1.2537 - val_accuracy: 0.4971
# Epoch 172/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9063 - accuracy: 0.6719
# Epoch 172: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 19ms/step - loss: 0.9011 - accuracy: 0.6776 - val_loss: 1.2538 - val_accuracy: 0.5145
# Epoch 173/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0722 - accuracy: 0.5859
# Epoch 173: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.9025 - accuracy: 0.6776 - val_loss: 1.2686 - val_accuracy: 0.5087
# Epoch 174/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.7904 - accuracy: 0.7422
# Epoch 174: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 0.8571 - accuracy: 0.6969 - val_loss: 1.2837 - val_accuracy: 0.5029
# Epoch 175/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8168 - accuracy: 0.7031
# Epoch 175: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 0.8827 - accuracy: 0.6795 - val_loss: 1.3052 - val_accuracy: 0.4509
# Epoch 176/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9690 - accuracy: 0.6172
# Epoch 176: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 22ms/step - loss: 0.9375 - accuracy: 0.6371 - val_loss: 1.2967 - val_accuracy: 0.4509
# Epoch 177/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9047 - accuracy: 0.6797
# Epoch 177: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.9213 - accuracy: 0.6776 - val_loss: 1.3644 - val_accuracy: 0.4566
# Epoch 178/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0542 - accuracy: 0.5625
# Epoch 178: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 0.9686 - accuracy: 0.6255 - val_loss: 1.4012 - val_accuracy: 0.4162
# Epoch 179/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9215 - accuracy: 0.6328
# Epoch 179: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 0.9276 - accuracy: 0.6313 - val_loss: 1.4218 - val_accuracy: 0.4335
# Epoch 180/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9948 - accuracy: 0.6406
# Epoch 180: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.9637 - accuracy: 0.6602 - val_loss: 1.3961 - val_accuracy: 0.4104
# Epoch 181/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9358 - accuracy: 0.6719
# Epoch 181: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.9814 - accuracy: 0.6332 - val_loss: 1.3345 - val_accuracy: 0.4335
# Epoch 182/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9229 - accuracy: 0.6250
# Epoch 182: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 0.9378 - accuracy: 0.6486 - val_loss: 1.3015 - val_accuracy: 0.4740
# Epoch 183/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0174 - accuracy: 0.6328
# Epoch 183: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.9355 - accuracy: 0.6602 - val_loss: 1.3347 - val_accuracy: 0.4624
# Epoch 184/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9007 - accuracy: 0.6953
# Epoch 184: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 24ms/step - loss: 0.9330 - accuracy: 0.6351 - val_loss: 1.3216 - val_accuracy: 0.4798
# Epoch 185/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8400 - accuracy: 0.7266
# Epoch 185: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.9219 - accuracy: 0.6737 - val_loss: 1.3137 - val_accuracy: 0.5029
# Epoch 186/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 1.0347 - accuracy: 0.5938
# Epoch 186: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 21ms/step - loss: 0.9437 - accuracy: 0.6544 - val_loss: 1.3548 - val_accuracy: 0.4798
# Epoch 187/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9072 - accuracy: 0.6484
# Epoch 187: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.9301 - accuracy: 0.6737 - val_loss: 1.3292 - val_accuracy: 0.5029
# Epoch 188/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9070 - accuracy: 0.6484
# Epoch 188: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 19ms/step - loss: 0.9529 - accuracy: 0.6371 - val_loss: 1.2830 - val_accuracy: 0.5260
# Epoch 189/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.9413 - accuracy: 0.6641
# Epoch 189: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.9291 - accuracy: 0.6680 - val_loss: 1.2904 - val_accuracy: 0.5145
# Epoch 190/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8648 - accuracy: 0.7188
# Epoch 190: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.9334 - accuracy: 0.6795 - val_loss: 1.2872 - val_accuracy: 0.5087
# Epoch 191/1000
# 1/5 [=====>........................] - ETA: 0s - loss: 0.8852 - accuracy: 0.7031
# Epoch 191: saving model to /content/drive/MyDrive/Colab Notebooks/JSL/model/LSTM/gesture_classifier.hdf5
# 5/5 [==============================] - 0s 20ms/step - loss: 0.8831 - accuracy: 0.6873 - val_loss: 1.2805 - val_accuracy: 0.4682
# Epoch 191: early stopping

# %%
input_dtype = model.input.dtype
print("Input data type:", input_dtype)
# Out:
# Input data type: <dtype: 'float32'>

# %%
# 推論テスト
predict_result = model.predict(np.array([X_test[0]]))

# 推論モデルとして保存
model.save(model_save_path, include_optimizer=False)
# Out:
# 1/1 [==============================] - 0s 401ms/step

# %% [markdown]
# ### 量子化

# %%
# 推論モデルを読み込み
import tensorflow as tf
from tensorflow import keras

#model_save_path = '/content/drive/MyDrive/Colab Notebooks/JSL/model/normal/gesture_classifier.hdf5'
#tflite_save_path = '/content/drive/MyDrive/Colab Notebooks/JSL/model/normal/keypoint_classifier.tflite'

model = tf.keras.models.load_model(model_save_path)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
# モデルを変換(量子化)
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# TensorFlow Liteでサポートされていない操作を含むモデルに対応するための設定
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS,tf.lite.OpsSet.SELECT_TF_OPS]

converter._experimental_lower_tensor_list_ops = False

tflite_quantized_model = converter.convert()
open(tflite_save_path, 'wb').write(tflite_quantized_model)
# Out:
# 113872

# %%
# 推論テスト
interpreter = tf.lite.Interpreter(model_path=tflite_save_path)
interpreter.allocate_tensors()

# 入出力テンソルを取得
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# 推論実施の前に、入力データを適切な形状にリシェイプ
input_data = np.array([X_dataset[0]]) #.reshape(1, TIME_STEPS, DIMENSION)

# 推論実施
interpreter.set_tensor(input_details[0]['index'], input_data)
interpreter.invoke()
tflite_results = interpreter.get_tensor(output_details[0]['index'])

print(np.squeeze(tflite_results))
print(np.argmax(np.squeeze(tflite_results)))
# Out:
# [4.58011200e-04 2.28388933e-03 2.18658228e-04 3.47645604e-03
#  1.16671401e-03 4.60269512e-04 5.35358023e-03 6.92924368e-06
#  2.60464791e-02 1.01229220e-04 8.05379706e-04 1.54490714e-04
#  2.45355128e-04 1.28673052e-03 1.26333471e-04 1.11885004e-06
#  1.18379677e-02 5.55776954e-01 1.64030101e-02 6.18561025e-05
#  1.04587860e-02 2.57740048e-05 1.00000550e-04 3.49430164e-04
#  6.86529484e-06 1.05260779e-05 3.59549049e-05 3.59084370e-05
#  8.33748054e-05 5.70532226e-04 2.37604370e-03 9.18250080e-05
#  1.49548441e-06 6.00326397e-02 1.77422971e-05 6.54513075e-04
#  6.13856828e-04 2.58867158e-06 1.91050513e-05 9.06567311e-06
#  1.99496444e-05 6.49983167e-06 1.54487782e-06 3.95983690e-03
#  4.76328743e-04 1.10206774e-05 5.33467683e-04 7.31285487e-04
#  1.15637602e-06 1.97615870e-03 1.25695160e-03 4.25126730e-03
#  4.06838881e-05 3.27729562e-04 2.67975440e-04 5.10538048e-05
#  4.31568924e-06 1.59999039e-02 1.21966064e-01 1.22506637e-02
#  9.77465606e-05 3.15506732e-05 2.17944871e-05 1.53733745e-05
#  4.52529730e-06 4.47291974e-03 1.76752164e-05 5.31305050e-05
#  3.68497160e-04 7.49252431e-05 1.69305457e-03 1.22983247e-01
#  8.20718240e-04 3.41886724e-03 7.47818513e-06 1.72872878e-05]
# 17

# %% [markdown]
# ### 入力テンソルの形状確認

# %%
# モデルのパス
tflite_model_path = tflite_save_path

# TensorFlow Lite インタープリタの初期化
interpreter = tf.lite.Interpreter(model_path=tflite_model_path)
interpreter.allocate_tensors()

# 入力ディテールの取得
input_details = interpreter.get_input_details()
print(input_details[0]['shape'])  # 入力テンソルの形状を表示
# Out:
# [ 1 30 40]
